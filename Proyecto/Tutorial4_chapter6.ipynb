# %% [markdown]
# Chapter 6:

# %%
# 1) Instalación de librerías y descargas de NLTK
import nltk
import pandas as pd
import random
from nltk import FreqDist
from nltk.classify import NaiveBayesClassifier, accuracy

nltk.download('punkt')
nltk.download('punkt_tab')

# 2) Carga del dataset
def load_data(path='Dataset/train.csv', sample_size=20000):
    df = pd.read_csv(path)
    df = df[['comment_text', 'toxic']].dropna().reset_index(drop=True)
    df['label'] = df['toxic'].map({1: 'toxic', 0: 'non_toxic'})
    return df.sample(sample_size, random_state=42).reset_index(drop=True)

# Cargar datos
df = load_data()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hugom\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hugom\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
# 3) Preprocesado y tokenización de los comentarios
import string

def preprocess_and_tokenize(text):
    # Convertir a minúsculas
    text = text.lower()
    # Eliminar puntuación
    text = ''.join(ch for ch in text if ch not in string.punctuation)
    # Tokenizar por palabras
    return nltk.word_tokenize(text)

# Aplicar preprocesado y tokenización
df['tokens'] = df['comment_text'].apply(preprocess_and_tokenize)

# Visualizamos un ejemplo
print(df[['comment_text','tokens']].head(1).to_dict(orient='records')[0])
# Out:
# {'comment_text': "Geez, are you forgetful!  We've already discussed why Marx  was  not an anarchist, i.e. he wanted to use a State to mold his 'socialist man.'  Ergo, he is a statist - the opposite of an  anarchist.  I know a guy who says that, when he gets old and his teeth fall out, he'll quit eating meat.  Would you call him a vegetarian?", 'tokens': ['geez', 'are', 'you', 'forgetful', 'weve', 'already', 'discussed', 'why', 'marx', 'was', 'not', 'an', 'anarchist', 'ie', 'he', 'wanted', 'to', 'use', 'a', 'state', 'to', 'mold', 'his', 'socialist', 'man', 'ergo', 'he', 'is', 'a', 'statist', 'the', 'opposite', 'of', 'an', 'anarchist', 'i', 'know', 'a', 'guy', 'who', 'says', 'that', 'when', 'he', 'gets', 'old', 'and', 'his', 'teeth', 'fall', 'out', 'hell', 'quit', 'eating', 'meat', 'would', 'you', 'call', 'him', 'a', 'vegetarian']}

# %%
# 4) Construcción del vocabulario (2000 palabras más frecuentes)
all_words = FreqDist(w for tokens in df['tokens'] for w in tokens)
word_features = list(all_words)[:5000]

print("Tamaño de vocabulario:", len(word_features))
print("Primeras 10 features:", word_features[:10])
# Out:
# Tamaño de vocabulario: 2000
# Primeras 10 features: ['the', 'to', 'of', 'a', 'and', 'you', 'i', 'is', 'that', 'in']

# %%
# 5) Definición del extractor de características
def document_features(tokens):
    token_set = set(tokens)
    return {f'contains({w})': (w in token_set) for w in word_features}

# Probamos el extractor con un ejemplo
test_feats = document_features(df.loc[0,'tokens'])
print(list(test_feats.items())[:10])
# Out:
# [('contains(the)', True), ('contains(to)', True), ('contains(of)', True), ('contains(a)', True), ('contains(and)', True), ('contains(you)', True), ('contains(i)', True), ('contains(is)', True), ('contains(that)', True), ('contains(in)', False)]

# %%
# 6) Preparar feature‐sets y división en train / dev‐test / test
featuresets = [(document_features(toks), lbl)
               for toks, lbl in zip(df['tokens'], df['label'])]
random.shuffle(featuresets)

n = len(featuresets)
n_train = int(0.7 * n)
n_dev = int(0.15 * n)

train_set = featuresets[:n_train]
dev_set   = featuresets[n_train:n_train+n_dev]
test_set  = featuresets[n_train+n_dev:]

print("Entrenamiento:", len(train_set), "Dev-test:", len(dev_set), "Test:", len(test_set))
# Out:
# Entrenamiento: 14000 Dev-test: 3000 Test: 3000

# %%
# 7) Entrenamiento del clasificador Naive Bayes
classifier = NaiveBayesClassifier.train(train_set)

# %%
# 8) Evaluación en dev-test
dev_acc = accuracy(classifier, dev_set)
print(f"Dev-Test Accuracy: {dev_acc:.4f}")
# Out:
# Dev-Test Accuracy: 0.6557

# %%
# 9) Features más informativos
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#           contains(fuck) = True            toxic : non_to =    259.9 : 1.0
#          contains(bitch) = True            toxic : non_to =    243.0 : 1.0
#        contains(fucking) = True            toxic : non_to =    151.5 : 1.0
#           contains(suck) = True            toxic : non_to =    124.2 : 1.0
#           contains(cock) = True            toxic : non_to =    118.6 : 1.0
#        contains(asshole) = True            toxic : non_to =    115.6 : 1.0
#         contains(faggot) = True            toxic : non_to =    114.7 : 1.0
#           contains(cunt) = True            toxic : non_to =     87.5 : 1.0
#       contains(retarded) = True            toxic : non_to =     87.5 : 1.0
#            contains(ass) = True            toxic : non_to =     55.4 : 1.0

# %%
# 10) Análisis de errores
errors = []
for feats, label in dev_set:
    guess = classifier.classify(feats)
    if guess != label:
        errors.append((label, guess, feats))

print(f"Número de errores en dev-test: {len(errors)}")
# Mostrar algunos ejemplos
errors[:5]
# Out:
# Número de errores en dev-test: 1033
# [('non_toxic',
#   'toxic',
#   {'contains(the)': True,
#    'contains(to)': False,
#    'contains(of)': False,
#    'contains(a)': False,
#    'contains(and)': False,
#    'contains(you)': False,
#    'contains(i)': False,
#    'contains(is)': True,
#    'contains(that)': False,
#    'contains(in)': False,
#    'contains(it)': False,
#    'contains(for)': False,
#    'contains(not)': False,
#    'contains(this)': False,
#    'contains(on)': False,
#    'contains(be)': False,
#    'contains(as)': False,
#    'contains(have)': False,
#    'contains(are)': False,
#    'contains(your)': False,
#    'contains(if)': False,
#    'contains(with)': False,
#    'contains(article)': False,
#    'contains(was)': False,
#    'contains(or)': False,
#    'contains(but)': False,
#    'contains(page)': False,
#    'contains(my)': False,
#    'contains(an)': False,
#    'contains(do)': False,
#    'contains(by)': False,
#    'contains(from)': False,
#    'contains(at)': False,
#    'contains(me)': False,
#    'contains(about)': False,
#    'contains(can)': False,
#    'contains(wikipedia)': False,
#    'contains(so)': False,
#    'contains(what)': False,
#    'contains(there)': False,
#    'contains(talk)': False,
#    'contains(all)': False,
#    'contains(please)': False,
#    'contains(has)': False,
#    'contains(its)': False,
#    'contains(no)': False,
#    'contains(will)': False,
#    'contains(would)': False,
#    'contains(dont)': False,
#    'contains(they)': False,
#    'contains(one)': False,
#    'contains(just)': False,
#    'contains(like)': False,
#    'contains(he)': False,
#    'contains(which)': False,
#    'contains(any)': False,
#    'contains(been)': False,
#    'contains(should)': False,
#    'contains(more)': False,
#    'contains(some)': False,
#    'contains(other)': False,
#    'contains(here)': False,
#    'contains(see)': False,
#    'contains(we)': False,
#    'contains(who)': False,
#    'contains(because)': False,
#    'contains(think)': False,
#    'contains(know)': False,
#    'contains(also)': False,
#    'contains(why)': False,
#    'contains(his)': False,
#    'contains(im)': False,
#    'contains(how)': False,
#    'contains(people)': False,
#    'contains(edit)': False,
#    'contains(only)': False,
#    'contains(up)': False,
#    'contains(articles)': False,
#    'contains(were)': False,
#    'contains(out)': False,
#    'contains(am)': False,
#    'contains(use)': False,
#    'contains(may)': False,
#    'contains(then)': False,
#    'contains(when)': False,
#    'contains(them)': False,
#    'contains(did)': False,
#    'contains(time)': False,
#    'contains(their)': False,
#    'contains(being)': False,
#    'contains(thanks)': False,
#    'contains(now)': False,
#    'contains(than)': False,
#    'contains(even)': False,
#    'contains(get)': False,
#    'contains(make)': False,
#    'contains(very)': False,
#    'contains(good)': False,
#    'contains(information)': False,
#    'contains(want)': False,
#    'contains(had)': False,
#    'contains(could)': False,
#    'contains(does)': False,
#    'contains(sources)': False,
#    'contains(well)': False,
#    'contains(deletion)': False,
#    'contains(such)': False,
#    'contains(name)': False,
#    'contains(way)': False,
#    'contains(new)': False,
#    'contains(pages)': False,
#    'contains(these)': False,
#    'contains(say)': False,
#    'contains(editing)': False,
#    'contains(need)': False,
#    'contains(help)': False,
#    'contains(section)': False,
#    'contains(source)': False,
#    'contains(user)': False,
#    'contains(thank)': False,
#    'contains(first)': False,
#    'contains(made)': False,
#    'contains(again)': False,
#    'contains(go)': False,
#    'contains(discussion)': False,
#    'contains(edits)': False,
#    'contains(many)': False,
#    'contains(where)': False,
#    'contains(deleted)': False,
#    'contains(really)': False,
#    'contains(much)': False,
#    'contains(used)': False,
#    'contains(find)': False,
#    'contains(same)': False,
#    'contains(most)': False,
#    'contains(those)': False,
#    'contains(ive)': False,
#    'contains(into)': False,
#    'contains(image)': False,
#    'contains(read)': False,
#    'contains(right)': False,
#    'contains(before)': False,
#    'contains(after)': False,
#    'contains(look)': False,
#    'contains(point)': False,
#    'contains(work)': False,
#    'contains(since)': False,
#    'contains(still)': False,
#    'contains(take)': False,
#    'contains(add)': False,
#    'contains(too)': False,
#    'contains(link)': False,
#    'contains(us)': False,
#    'contains(content)': False,
#    'contains(fact)': False,
#    'contains(him)': False,
#    'contains(over)': False,
#    'contains(said)': False,
#    'contains(list)': False,
#    'contains(back)': False,
#    'contains(two)': False,
#    'contains(someone)': False,
#    'contains(under)': False,
#    'contains(editors)': False,
#    'contains(own)': False,
#    'contains(stop)': False,
#    'contains(something)': False,
#    'contains(cant)': False,
#    'contains(going)': False,
#    'contains(our)': False,
#    'contains(without)': False,
#    'contains(blocked)': False,
#    'contains(youre)': False,
#    'contains(removed)': False,
#    'contains(added)': False,
#    'contains(doesnt)': False,
#    'contains(utc)': False,
#    'contains(thats)': False,
#    'contains(might)': False,
#    'contains(both)': False,
#    'contains(actually)': False,
#    'contains(place)': False,
#    'contains(however)': False,
#    'contains(welcome)': False,
#    'contains(block)': False,
#    'contains(history)': False,
#    'contains(note)': False,
#    'contains(done)': False,
#    'contains(another)': False,
#    'contains(vandalism)': False,
#    'contains(sure)': False,
#    'contains(believe)': False,
#    'contains(case)': False,
#    'contains(while)': False,
#    'contains(comment)': False,
#    'contains(keep)': False,
#    'contains(her)': False,
#    'contains(better)': False,
#    'contains(things)': False,
#    'contains(put)': False,
#    'contains(feel)': False,
#    'contains(never)': False,
#    'contains(personal)': False,
#    'contains(seems)': False,
#    'contains(comments)': False,
#    'contains(anything)': False,
#    'contains(links)': False,
#    'contains(free)': False,
#    'contains(reason)': False,
#    'contains(using)': False,
#    'contains(fuck)': False,
#    'contains(question)': False,
#    'contains(hope)': False,
#    'contains(ask)': False,
#    'contains(part)': False,
#    'contains(didnt)': False,
#    'contains(ill)': False,
#    'contains(hate)': False,
#    'contains(against)': False,
#    'contains(care)': False,
#    'contains(give)': False,
#    'contains(change)': False,
#    'contains(thing)': False,
#    'contains(subject)': False,
#    'contains(tag)': False,
#    'contains(wrong)': False,
#    'contains(anyone)': False,
#    'contains(little)': False,
#    'contains(hi)': False,
#    'contains(remove)': False,
#    'contains(•)': False,
#    'contains(copyright)': False,
#    'contains(person)': False,
#    'contains(policy)': False,
#    'contains(nothing)': False,
#    'contains(dickhead)': False,
#    'contains(teabag)': False,
#    'contains(rather)': False,
#    'contains(already)': False,
#    'contains(though)': False,
#    'contains(yourself)': False,
#    'contains(above)': False,
#    'contains(problem)': False,
#    'contains(others)': False,
#    'contains(issue)': False,
#    'contains(speedy)': False,
#    'contains(few)': False,
#    'contains(must)': False,
#    'contains(reliable)': False,
#    'contains(nigger)': False,
#    'contains(site)': False,
#    'contains(off)': False,
#    'contains(questions)': False,
#    'contains(different)': False,
#    'contains(trying)': False,
#    'contains(—)': False,
#    'contains(understand)': False,
#    'contains(isnt)': False,
#    'contains(editor)': False,
#    'contains(down)': False,
#    'contains(2)': False,
#    'contains(long)': False,
#    'contains(years)': False,
#    'contains(she)': False,
#    'contains(sorry)': False,
#    'contains(wiki)': False,
#    'contains(world)': False,
#    'contains(making)': False,
#    'contains(got)': False,
#    'contains(references)': False,
#    'contains(opinion)': False,
#    'contains(mean)': False,
#    'contains(last)': False,
#    'contains(best)': False,
#    'contains(great)': False,
#    'contains(agree)': False,
#    'contains(continue)': False,
#    'contains(reference)': False,
#    'contains(hello)': False,
#    'contains(found)': False,
#    'contains(text)': False,
#    'contains(state)': False,
#    'contains(let)': False,
#    'contains(1)': False,
#    'contains(doing)': False,
#    'contains(either)': False,
#    'contains(leave)': False,
#    'contains(images)': False,
#    'contains(thought)': False,
#    'contains(tell)': False,
#    'contains(matter)': False,
#    'contains(life)': False,
#    'contains(every)': False,
#    'contains(huge)': False,
#    'contains(notable)': False,
#    'contains(example)': False,
#    'contains(created)': False,
#    'contains(show)': False,
#    'contains(english)': False,
#    'contains(fair)': False,
#    'contains(try)': False,
#    'contains(far)': False,
#    'contains(adding)': False,
#    'contains(says)': False,
#    'contains(contributions)': False,
#    'contains(day)': False,
#    'contains(least)': False,
#    'contains(around)': False,
#    'contains(id)': False,
#    'contains(having)': False,
#    'contains(delete)': False,
#    'contains(encyclopedia)': False,
#    'contains(word)': False,
#    'contains(come)': False,
#    'contains(reverted)': False,
#    'contains(consensus)': False,
#    'contains(enough)': False,
#    'contains(ip)': False,
#    'contains(real)': False,
#    'contains(probably)': False,
#    'contains(users)': False,
#    'contains(media)': False,
#    'contains(yes)': False,
#    'contains(given)': False,
#    'contains(through)': False,
#    'contains(war)': False,
#    'contains(simply)': False,
#    'contains(bullshit)': False,
#    'contains(between)': False,
#    'contains(faggot)': False,
#    'contains(clear)': False,
#    'contains(else)': False,
#    'contains(idea)': False,
#    'contains(yet)': False,
#    'contains(correct)': False,
#    'contains(seem)': False,
#    'contains(original)': False,
#    'contains(request)': False,
#    'contains(clearly)': False,
#    'contains(needs)': False,
#    'contains(etc)': False,
#    'contains(consider)': False,
#    'contains(ever)': False,
#    'contains(check)': False,
#    'contains(write)': False,
#    'contains(number)': False,
#    'contains(lot)': False,
#    'contains(pov)': False,
#    'contains(material)': False,
#    'contains(evidence)': False,
#    'contains(view)': False,
#    'contains(states)': False,
#    'contains(3)': False,
#    'contains(quite)': False,
#    'contains(perhaps)': False,
#    'contains(stupid)': False,
#    'contains(instead)': False,
#    'contains(message)': False,
#    'contains(true)': False,
#    'contains(old)': False,
#    'contains(called)': False,
#    'contains(criteria)': False,
#    'contains(support)': False,
#    'contains(until)': False,
#    'contains(written)': False,
#    'contains(post)': False,
#    'contains(saying)': False,
#    'contains(several)': False,
#    'contains(admin)': False,
#    'contains(once)': False,
#    'contains(guidelines)': False,
#    'contains(book)': False,
#    'contains(account)': False,
#    'contains(maybe)': False,
#    'contains(listed)': False,
#    'contains(theres)': False,
#    'contains(fucking)': False,
#    'contains(important)': False,
#    'contains(bit)': False,
#    'contains(group)': False,
#    'contains(title)': False,
#    'contains(changes)': False,
#    'contains(always)': False,
#    'contains(love)': False,
#    'contains(makes)': False,
#    'contains(whether)': False,
#    'contains(words)': False,
#    'contains(further)': False,
#    'contains(mention)': False,
#    'contains(revert)': False,
#    'contains(times)': False,
#    'contains(website)': False,
#    'contains(review)': False,
#    'contains(live)': False,
#    'contains(considered)': False,
#    'contains(term)': False,
#    'contains(version)': False,
#    'contains(following)': False,
#    'contains(regarding)': False,
#    'contains(research)': False,
#    'contains(claim)': False,
#    'contains(means)': False,
#    'contains(language)': False,
#    'contains(bad)': False,
#    'contains(suggest)': False,
#    'contains(main)': False,
#    'contains(address)': False,
#    'contains(kind)': False,
#    'contains(’)': False,
#    'contains(possible)': False,
#    'contains(general)': False,
#    'contains(each)': False,
#    'contains(current)': False,
#    'contains(left)': False,
#    'contains(boobs)': False,
#    'contains(call)': False,
#    'contains(attack)': False,
#    'contains(top)': False,
#    'contains(offfuck)': False,
#    'contains(ok)': False,
#    'contains(statement)': False,
#    'contains(getting)': False,
#    'contains(less)': False,
#    'contains(year)': False,
#    'contains(facts)': False,
#    'contains(second)': False,
#    'contains(man)': False,
#    'contains(whole)': False,
#    'contains(mentioned)': False,
#    'contains(seen)': False,
#    'contains(based)': False,
#    'contains(known)': False,
#    'contains(issues)': False,
#    'contains(topic)': False,
#    'contains(looking)': False,
#    'contains(provide)': False,
#    'contains(start)': False,
#    'contains(boy)': False,
#    'contains(notability)': False,
#    'contains(notice)': False,
#    'contains(template)': False,
#    'contains(answer)': False,
#    'contains(redirect)': False,
#    'contains(guys)': False,
#    'contains(end)': False,
#    'contains(anyway)': False,
#    'contains(interested)': False,
#    'contains(explain)': False,
#    'contains(deneidaccess)': False,
#    'contains(appropriate)': False,
#    'contains(discuss)': False,
#    'contains(create)': False,
#    'contains(course)': False,
#    'contains(happy)': False,
#    'contains(big)': False,
#    'contains(included)': False,
#    'contains(wikipedias)': False,
#    'contains(days)': False,
#    'contains(three)': False,
#    'contains(hey)': False,
#    'contains(away)': False,
#    'contains(info)': False,
#    'contains(sense)': False,
#    'contains(sentence)': False,
#    'contains(include)': False,
#    'contains(per)': False,
#    'contains(shall)': False,
#    'contains(order)': False,
#    'contains(american)': False,
#    'contains(writing)': False,
#    'contains(u)': False,
#    'contains(including)': False,
#    'contains(relevant)': False,
#    'contains(appears)': False,
#    'contains(changed)': False,
#    'contains(line)': False,
#    'contains(full)': False,
#    'contains(rules)': False,
#    'contains(picture)': False,
#    'contains(removing)': False,
#    'contains(style)': False,
#    'contains(date)': False,
#    'contains(according)': False,
#    'contains(related)': False,
#    'contains(due)': False,
#    'contains(project)': False,
#    'contains(later)': False,
#    'contains(web)': False,
#    'contains(god)': False,
#    'contains(although)': False,
#    'contains(currently)': False,
#    'contains(move)': False,
#    'contains(oh)': False,
#    'contains(warning)': False,
#    'contains(within)': False,
#    'contains(common)': False,
#    'contains(s)': False,
#    'contains(certainly)': False,
#    'contains(policies)': False,
#    'contains(myself)': False,
#    'contains(involved)': False,
#    'contains(public)': False,
#    'contains(names)': False,
#    'contains(therefore)': False,
#    'contains(wasnt)': False,
#    'contains(youve)': False,
#    'contains(started)': False,
#    'contains(everything)': False,
#    'contains(claims)': False,
#    'contains(four)': False,
#    'contains(position)': False,
#    'contains(nice)': False,
#    'contains(united)': False,
#    'contains(below)': False,
#    'contains(everyone)': False,
#    'contains(interest)': False,
#    'contains(during)': False,
#    'contains(report)': False,
#    'contains(sign)': False,
#    'contains(response)': False,
#    'contains(false)': False,
#    'contains(wish)': False,
#    'contains(especially)': False,
#    'contains(reasons)': False,
#    'contains(next)': False,
#    'contains(recent)': False,
#    'contains(taken)': False,
#    'contains(stuff)': False,
#    'contains(uploaded)': False,
#    'contains(completely)': False,
#    'contains(specific)': False,
#    'contains(appreciate)': False,
#    'contains(mind)': False,
#    'contains(mamas)': False,
#    'contains(able)': False,
#    'contains(attacks)': False,
#    'contains(community)': False,
#    'contains(2005)': False,
#    'contains(contribs)': False,
#    'contains(wont)': False,
#    'contains(asked)': False,
#    'contains(today)': False,
#    'contains(guess)': False,
#    'contains(hard)': False,
#    'contains(news)': False,
#    'contains(looks)': False,
#    'contains(similar)': False,
#    'contains(4)': False,
#    'contains(pretty)': False,
#    'contains(itself)': False,
#    'contains(lead)': False,
#    'contains(system)': False,
#    'contains(neutral)': False,
#    'contains(wanted)': False,
#    'contains(school)': False,
#    'contains(edited)': False,
#    'contains(obviously)': False,
#    'contains(country)': False,
#    'contains(paragraph)': False,
#    'contains(boymamas)': False,
#    'contains(official)': False,
#    'contains(single)': False,
#    'contains(past)': False,
#    'contains(game)': False,
#    'contains(nor)': False,
#    'contains(5)': False,
#    'contains(email)': False,
#    'contains(learn)': False,
#    'contains(summary)': False,
#    'contains(process)': False,
#    'contains(whatever)': False,
#    'contains(unless)': False,
#    'contains(dispute)': False,
#    'contains(talking)': False,
#    'contains(themselves)': False,
#    'contains(“)': False,
#    'contains(quote)': False,
#    'contains(points)': False,
#    'contains(placed)': False,
#    'contains(remember)': False,
#    'contains(faith)': False,
#    'contains(penis)': False,
#    'contains(shit)': False,
#    'contains(political)': False,
#    'contains(useful)': False,
#    'contains(provided)': False,
#    'contains(particular)': False,
#    'contains(power)': False,
#    'contains(future)': False,
#    'contains(search)': False,
#    'contains(entry)': False,
#    'contains(wrote)': False,
#    'contains(anonymous)': False,
#    'contains(published)': False,
#    'contains(stay)': False,
#    'contains(came)': False,
#    'contains(side)': False,
#    'contains(working)': False,
#    'contains(status)': False,
#    'contains(ago)': False,
#    'contains(reading)': False,
#    'contains(admins)': False,
#    'contains(havent)': False,
#    'contains(recently)': False,
#    'contains(present)': False,
#    'contains(argument)': False,
#    'contains(reverting)': False,
#    'contains(exactly)': False,
#    'contains(knowledge)': False,
#    'contains(british)': False,
#    'contains(government)': False,
#    'contains(rule)': False,
#    'contains(noticed)': False,
#    'contains(lets)': False,
#    'contains(cheers)': False,
#    'contains(terms)': False,
#    'contains(books)': False,
#    'contains(takes)': False,
#    'contains(fine)': False,
#    'contains(vandalize)': False,
#    'contains(city)': False,
#    'contains(truth)': False,
#    'contains(tags)': False,
#    'contains(sandbox)': False,
#    'contains(”)': False,
#    'contains(ones)': False,
#    'contains(appear)': False,
#    'contains(often)': False,
#    'contains(hes)': False,
#    'contains(views)': False,
#    'contains(rape)': False,
#    'contains(major)': False,
#    'contains(regards)': False,
#    'contains(deleting)': False,
#    'contains(description)': True,
#    'contains(follow)': False,
#    'contains(definition)': False,
#    'contains(google)': False,
#    'contains(problems)': False,
#    'contains(become)': False,
#    'contains(saw)': False,
#    'contains(company)': False,
#    'contains(music)': False,
#    'contains(taking)': False,
#    'contains(t)': False,
#    'contains(along)': False,
#    'contains(explanation)': False,
#    'contains(moved)': False,
#    'contains(generally)': False,
#    'contains(username)': False,
#    'contains(2007)': False,
#    'contains(proper)': False,
#    'contains(law)': False,
#    'contains(administrator)': False,
#    'contains(film)': False,
#    'contains(attention)': False,
#    'contains(improve)': False,
#    'contains(posted)': False,
#    'contains(otherwise)': False,
#    'contains(aware)': False,
#    'contains(needed)': False,
#    'contains(valid)': False,
#    'contains(alone)': False,
#    'contains(external)': False,
#    'contains(band)': False,
#    'contains(five)': False,
#    'contains(shows)': False,
#    'contains(likely)': False,
#    'contains(disagree)': False,
#    'contains(sort)': False,
#    'contains(wp)': False,
#    'contains(almost)': False,
#    'contains(ie)': False,
#    'contains(arent)': False,
#    'contains(2004)': False,
#    'contains(bastard)': False,
#    'contains(indeed)': False,
#    'contains(party)': False,
#    'contains(10)': False,
#    'contains(shouldnt)': False,
#    'contains(certain)': False,
#    'contains(form)': False,
#    'contains(set)': False,
#    'contains(c)': False,
#    'contains(file)': False,
#    'contains(contributing)': False,
#    'contains(hell)': False,
#    'contains(allowed)': False,
#    'contains(sections)': False,
#    'contains(stated)': False,
#    'contains(took)': False,
#    'contains(2008)': False,
#    'contains(high)': False,
#    'contains(thus)': False,
#    'contains(available)': False,
#    'contains(national)': False,
#    'contains(team)': False,
#    'contains(2006)': False,
#    'contains(simple)': False,
#    'contains(whats)': False,
#    'contains(internet)': False,
#    'contains(small)': False,
#    'contains(mr)': False,
#    'contains(entire)': False,
#    'contains(guy)': False,
#    'contains(works)': False,
#    'contains(re)': False,
#    'contains(tagged)': False,
#    'contains(actions)': False,
#    'contains(interesting)': False,
#    'contains(citations)': False,
#    'contains(citation)': False,
#    'contains(greek)': False,
#    'contains(bias)': False,
#    'contains(rights)': False,
#    'contains(cited)': False,
#    'contains(members)': False,
#    'contains(tried)': False,
#    'contains(short)': False,
#    'contains(longer)': False,
#    'contains(area)': False,
#    'contains(obvious)': False,
#    'contains(banned)': False,
#    'contains(proposed)': False,
#    'contains(large)': False,
#    'contains(decide)': False,
#    'contains(fggt)': False,
#    'contains(wouldnt)': False,
#    'contains(sites)': False,
#    'contains(happened)': False,
#    'contains(various)': False,
#    'contains(sourced)': False,
#    'contains(result)': False,
#    'contains(npov)': False,
#    'contains(open)': False,
#    'contains(addition)': False,
#    'contains(week)': False,
#    'contains(together)': False,
#    'contains(contact)': False,
#    'contains(act)': False,
#    'contains(test)': False,
#    'contains(actual)': False,
#    'contains(john)': False,
#    'contains(category)': False,
#    'contains(type)': False,
#    'contains(accurate)': False,
#    'contains(exist)': False,
#    'contains(yeah)': False,
#    'contains(author)': False,
#    'contains(chicken)': False,
#    'contains(deletedthis)': False,
#    'contains(family)': False,
#    'contains(biased)': False,
#    'contains(goes)': False,
#    'contains(–)': False,
#    'contains(force)': False,
#    'contains(enjoy)': False,
#    'contains(context)': False,
#    'contains(himself)': False,
#    'contains(upon)': False,
#    'contains(speak)': False,
#    'contains(fan1967)': False,
#    'contains(indicate)': False,
#    'contains(theory)': False,
#    'contains(military)': False,
#    'contains(reply)': False,
#    'contains(story)': False,
#    'contains(2010)': False,
#    'contains(worked)': False,
#    'contains(white)': False,
#    'contains(level)': False,
#    'contains(licker)': False,
#    'contains(avoid)': False,
#    'contains(attempt)': False,
#    'contains(serious)': False,
#    'contains(hand)': False,
#    'contains(seriously)': False,
#    'contains(comes)': False,
#    'contains(violation)': False,
#    'contains(told)': False,
#    'contains(criticism)': False,
#    'contains(went)': False,
#    'contains(action)': False,
#    'contains(human)': False,
#    'contains(german)': False,
#    'contains(copy)': False,
#    'contains(b)': False,
#    'contains(hours)': False,
#    'contains(proof)': False,
#    'contains(deal)': False,
#    'contains(nonsense)': False,
#    'contains(automatically)': False,
#    'contains(assume)': False,
#    'contains(difference)': False,
#    'contains(helpful)': False,
#    'contains(cite)': False,
#    'contains(accept)': False,
#    'contains(doubt)': False,
#    'contains(face)': False,
#    'contains(church)': False,
#    'contains(soon)': False,
#    'contains(uk)': False,
#    'contains(rationale)': False,
#    'contains(multiple)': False,
#    'contains(record)': False,
#    'contains(cause)': False,
#    'contains(theyre)': False,
#    'contains(opinions)': False,
#    'contains(complete)': False,
#    'contains(science)': False,
#    'contains(ricehey)': False,
#    'contains(space)': False,
#    'contains(conflict)': False,
#    'contains(specifically)': False,
#    'contains(death)': False,
#    'contains(online)': False,
#    'contains(personally)': False,
#    'contains(significant)': False,
#    'contains(gay)': False,
#    'contains(earlier)': False,
#    'contains(sometimes)': False,
#    'contains(outside)': False,
#    'contains(job)': False,
#    'contains(respect)': False,
#    'contains(details)': False,
#    'contains(youll)': False,
#    'contains(necessary)': False,
#    'contains(neither)': False,
#    'contains(purpose)': False,
#    'contains(series)': False,
#    'contains(period)': False,
#    'contains(asking)': False,
#    'contains(inclusion)': False,
#    'contains(accepted)': False,
#    'contains(previous)': False,
#    'contains(calling)': False,
#    'contains(philippineslong)': False,
#    'contains(gets)': False,
#    'contains(separate)': False,
#    'contains(situation)': False,
#    'contains(box)': False,
#    'contains(ban)': False,
#    'contains(heard)': False,
#    'contains(discussed)': False,
#    'contains(none)': False,
#    'contains(months)': False,
#    'contains(statements)': False,
#    'contains(tildes)': False,
#    'contains(supposed)': False,
#    'contains(mongo)': False,
#    'contains(numbers)': False,
#    'contains(subjects)': False,
#    'contains(unfortunately)': False,
#    'contains(black)': False,
#    'contains(incorrect)': False,
#    'contains(gave)': False,
#    'contains(character)': False,
#    'contains(legal)': False,
#    'contains(explaining)': False,
#    'contains(behavior)': False,
#    'contains(prove)': False,
#    'contains(wikiproject)': False,
#    'contains(weezer)': False,
#    'contains(bring)': False,
#    'contains(afd)': False,
#    'contains(standard)': False,
#    'contains(lost)': False,
#    'contains(computer)': False,
#    'contains(million)': False,
#    'contains(okay)': False,
#    'contains(fix)': False,
#    'contains(okayis)': False,
#    'contains(manual)': False,
#    'contains(friend)': False,
#    'contains(20)': False,
#    'contains(particularly)': False,
#    'contains(cases)': False,
#    'contains(release)': False,
#    'contains(usually)': False,
#    'contains(living)': False,
#    'contains(head)': False,
#    'contains(uses)': False,
#    'contains(except)': False,
#    'contains(coming)': False,
#    'contains(rest)': False,
#    'contains(field)': False,
#    'contains(6)': False,
#    'contains(concerns)': False,
#    'contains(couple)': False,
#    'contains(piece)': False,
#    'contains(described)': False,
#    'contains(civil)': False,
#    'contains(examples)': False,
#    'contains(existing)': False,
#    'contains(thinking)': False,
#    'contains(linked)': False,
#    'contains(changing)': False,
#    'contains(directly)': False,
#    'contains(wikipedian)': False,
#    'contains(french)': False,
#    'contains(july)': False,
#    'contains(among)': False,
#    'contains(happen)': False,
#    'contains(possibly)': False,
#    'contains(entirely)': False,
#    'contains(album)': False,
#    'contains(creating)': False,
#    'contains(debate)': False,
#    'contains(data)': False,
#    'contains(song)': False,
#    'contains(june)': False,
#    'contains(refer)': False,
#    'contains(contribute)': False,
#    'contains(verifiable)': False,
#    'contains(7)': False,
#    'contains(october)': False,
#    'contains(play)': False,
#    'contains(removal)': False,
#    'contains(totally)': False,
#    'contains(blocking)': False,
#    'contains(2009)': False,
#    'contains(decision)': False,
#    'contains(jews)': False,
#    'contains(lack)': False,
#    'contains(readers)': False,
#    'contains(reported)': False,
#    'contains(culture)': False,
#    'contains(unblock)': False,
#    'contains(meaning)': False,
#    'contains(sucks)': False,
#    'contains(across)': False,
#    'contains(third)': False,
#    'contains(despite)': False,
#    'contains(majority)': False,
#    'contains(august)': False,
#    'contains(photo)': False,
#    'contains(club)': False,
#    'contains(noted)': False,
#    'contains(early)': False,
#    'contains(vs)': False,
#    'contains(historical)': False,
#    'contains(close)': False,
#    'contains(putting)': False,
#    'contains(final)': False,
#    'contains(disruptive)': False,
#    'contains(100)': False,
#    'contains(meet)': False,
#    'contains(access)': False,
#    'contains(friends)': False,
#    'contains(court)': False,
#    'contains(meant)': False,
#    'contains(absolutely)': False,
#    'contains(modern)': False,
#    'contains(groups)': False,
#    'contains(video)': False,
#    'contains(websites)': False,
#    'contains(knows)': False,
#    'contains(wait)': False,
#    'contains(chance)': False,
#    'contains(run)': False,
#    'contains(contest)': False,
#    'contains(primary)': False,
#    'contains(easy)': False,
#    'contains(pillars)': False,
#    'contains(christian)': False,
#    'contains(loser)': False,
#    'contains(religion)': False,
#    'contains(8)': False,
#    'contains(university)': False,
#    'contains(results)': False,
#    'contains(home)': False,
#    'contains(pictures)': False,
#    'contains(born)': False,
#    'contains(straight)': False,
#    'contains(events)': False,
#    'contains(unsigned)': False,
#    'contains(towards)': False,
#    'contains(member)': False,
#    'contains(24)': False,
#    'contains(posts)': False,
#    'contains(youd)': False,
#    'contains(eg)': False,
#    'contains(standards)': False,
#    'contains(error)': False,
#    'contains(scientific)': False,
#    'contains(dear)': False,
#    'contains(tutorial)': False,
#    'contains(discussing)': False,
#    'contains(countries)': False,
#    'contains(inappropriate)': False,
#    'contains(control)': False,
#    'contains(body)': False,
#    'contains(march)': False,
#    'contains(behind)': False,
#    'contains(service)': False,
#    'contains(giving)': False,
#    'contains(decided)': False,
#    'contains(named)': False,
#    'contains(2011)': False,
#    'contains(quality)': False,
#    ...}),
#  ('toxic',
#   'non_toxic',
#   {'contains(the)': True,
#    'contains(to)': True,
#    'contains(of)': True,
#    'contains(a)': True,
#    'contains(and)': True,
#    'contains(you)': True,
#    'contains(i)': True,
#    'contains(is)': True,
#    'contains(that)': True,
#    'contains(in)': True,
#    'contains(it)': True,
#    'contains(for)': True,
#    'contains(not)': True,
#    'contains(this)': True,
#    'contains(on)': False,
#    'contains(be)': True,
#    'contains(as)': False,
#    'contains(have)': True,
#    'contains(are)': False,
#    'contains(your)': True,
#    'contains(if)': True,
#    'contains(with)': True,
#    'contains(article)': True,
#    'contains(was)': True,
#    'contains(or)': False,
#    'contains(but)': False,
#    'contains(page)': False,
#    'contains(my)': True,
#    'contains(an)': True,
#    'contains(do)': True,
#    'contains(by)': True,
#    'contains(from)': False,
#    'contains(at)': False,
#    'contains(me)': False,
#    'contains(about)': True,
#    'contains(can)': False,
#    'contains(wikipedia)': True,
#    'contains(so)': False,
#    'contains(what)': False,
#    'contains(there)': True,
#    'contains(talk)': False,
#    'contains(all)': False,
#    'contains(please)': True,
#    'contains(has)': False,
#    'contains(its)': True,
#    'contains(no)': True,
#    'contains(will)': False,
#    'contains(would)': False,
#    'contains(dont)': False,
#    'contains(they)': False,
#    'contains(one)': False,
#    'contains(just)': False,
#    'contains(like)': False,
#    'contains(he)': False,
#    'contains(which)': False,
#    'contains(any)': False,
#    'contains(been)': False,
#    'contains(should)': False,
#    'contains(more)': False,
#    'contains(some)': False,
#    'contains(other)': False,
#    'contains(here)': False,
#    'contains(see)': False,
#    'contains(we)': True,
#    'contains(who)': False,
#    'contains(because)': False,
#    'contains(think)': False,
#    'contains(know)': False,
#    'contains(also)': True,
#    'contains(why)': False,
#    'contains(his)': False,
#    'contains(im)': False,
#    'contains(how)': False,
#    'contains(people)': False,
#    'contains(edit)': True,
#    'contains(only)': False,
#    'contains(up)': False,
#    'contains(articles)': True,
#    'contains(were)': False,
#    'contains(out)': False,
#    'contains(am)': False,
#    'contains(use)': False,
#    'contains(may)': True,
#    'contains(then)': False,
#    'contains(when)': False,
#    'contains(them)': False,
#    'contains(did)': False,
#    'contains(time)': False,
#    'contains(their)': False,
#    'contains(being)': False,
#    'contains(thanks)': True,
#    'contains(now)': False,
#    'contains(than)': False,
#    'contains(even)': False,
#    'contains(get)': False,
#    'contains(make)': False,
#    'contains(very)': False,
#    'contains(good)': False,
#    'contains(information)': True,
#    'contains(want)': False,
#    'contains(had)': False,
#    'contains(could)': False,
#    'contains(does)': False,
#    'contains(sources)': False,
#    'contains(well)': False,
#    'contains(deletion)': False,
#    'contains(such)': False,
#    'contains(name)': False,
#    'contains(way)': False,
#    'contains(new)': False,
#    'contains(pages)': False,
#    'contains(these)': False,
#    'contains(say)': False,
#    'contains(editing)': False,
#    'contains(need)': False,
#    'contains(help)': False,
#    'contains(section)': False,
#    'contains(source)': False,
#    'contains(user)': False,
#    'contains(thank)': False,
#    'contains(first)': False,
#    'contains(made)': False,
#    'contains(again)': True,
#    'contains(go)': False,
#    'contains(discussion)': False,
#    'contains(edits)': False,
#    'contains(many)': False,
#    'contains(where)': False,
#    'contains(deleted)': False,
#    'contains(really)': False,
#    'contains(much)': False,
#    'contains(used)': False,
#    'contains(find)': False,
#    'contains(same)': False,
#    'contains(most)': False,
#    'contains(those)': False,
#    'contains(ive)': False,
#    'contains(into)': True,
#    'contains(image)': False,
#    'contains(read)': False,
#    'contains(right)': False,
#    'contains(before)': False,
#    'contains(after)': False,
#    'contains(look)': False,
#    'contains(point)': False,
#    'contains(work)': False,
#    'contains(since)': False,
#    'contains(still)': False,
#    'contains(take)': False,
#    'contains(add)': False,
#    'contains(too)': False,
#    'contains(link)': False,
#    'contains(us)': False,
#    'contains(content)': False,
#    'contains(fact)': False,
#    'contains(him)': False,
#    'contains(over)': False,
#    'contains(said)': False,
#    'contains(list)': False,
#    'contains(back)': False,
#    'contains(two)': False,
#    'contains(someone)': False,
#    'contains(under)': False,
#    'contains(editors)': False,
#    'contains(own)': False,
#    'contains(stop)': False,
#    'contains(something)': False,
#    'contains(cant)': False,
#    'contains(going)': False,
#    'contains(our)': False,
#    'contains(without)': False,
#    'contains(blocked)': False,
#    'contains(youre)': False,
#    'contains(removed)': True,
#    'contains(added)': False,
#    'contains(doesnt)': False,
#    'contains(utc)': False,
#    'contains(thats)': False,
#    'contains(might)': False,
#    'contains(both)': False,
#    'contains(actually)': False,
#    'contains(place)': False,
#    'contains(however)': False,
#    'contains(welcome)': False,
#    'contains(block)': False,
#    'contains(history)': False,
#    'contains(note)': False,
#    'contains(done)': False,
#    'contains(another)': False,
#    'contains(vandalism)': True,
#    'contains(sure)': False,
#    'contains(believe)': False,
#    'contains(case)': False,
#    'contains(while)': False,
#    'contains(comment)': False,
#    'contains(keep)': False,
#    'contains(her)': False,
#    'contains(better)': False,
#    'contains(things)': False,
#    'contains(put)': False,
#    'contains(feel)': False,
#    'contains(never)': False,
#    'contains(personal)': False,
#    'contains(seems)': False,
#    'contains(comments)': False,
#    'contains(anything)': False,
#    'contains(links)': False,
#    'contains(free)': False,
#    'contains(reason)': False,
#    'contains(using)': False,
#    'contains(fuck)': False,
#    'contains(question)': False,
#    'contains(hope)': False,
#    'contains(ask)': False,
#    'contains(part)': False,
#    'contains(didnt)': False,
#    'contains(ill)': False,
#    'contains(hate)': False,
#    'contains(against)': False,
#    'contains(care)': False,
#    'contains(give)': False,
#    'contains(change)': False,
#    'contains(thing)': False,
#    'contains(subject)': False,
#    'contains(tag)': False,
#    'contains(wrong)': False,
#    'contains(anyone)': False,
#    'contains(little)': False,
#    'contains(hi)': False,
#    'contains(remove)': False,
#    'contains(•)': False,
#    'contains(copyright)': False,
#    'contains(person)': False,
#    'contains(policy)': False,
#    'contains(nothing)': False,
#    'contains(dickhead)': False,
#    'contains(teabag)': False,
#    'contains(rather)': False,
#    'contains(already)': False,
#    'contains(though)': False,
#    'contains(yourself)': False,
#    'contains(above)': True,
#    'contains(problem)': False,
#    'contains(others)': False,
#    'contains(issue)': False,
#    'contains(speedy)': False,
#    'contains(few)': False,
#    'contains(must)': False,
#    'contains(reliable)': False,
#    'contains(nigger)': False,
#    'contains(site)': False,
#    'contains(off)': False,
#    'contains(questions)': True,
#    'contains(different)': False,
#    'contains(trying)': False,
#    'contains(—)': False,
#    'contains(understand)': False,
#    'contains(isnt)': False,
#    'contains(editor)': False,
#    'contains(down)': False,
#    'contains(2)': False,
#    'contains(long)': False,
#    'contains(years)': False,
#    'contains(she)': False,
#    'contains(sorry)': True,
#    'contains(wiki)': False,
#    'contains(world)': False,
#    'contains(making)': False,
#    'contains(got)': False,
#    'contains(references)': False,
#    'contains(opinion)': False,
#    'contains(mean)': False,
#    'contains(last)': False,
#    'contains(best)': False,
#    'contains(great)': False,
#    'contains(agree)': False,
#    'contains(continue)': False,
#    'contains(reference)': False,
#    'contains(hello)': False,
#    'contains(found)': False,
#    'contains(text)': False,
#    'contains(state)': False,
#    'contains(let)': False,
#    'contains(1)': False,
#    'contains(doing)': False,
#    'contains(either)': False,
#    'contains(leave)': False,
#    'contains(images)': False,
#    'contains(thought)': False,
#    'contains(tell)': False,
#    'contains(matter)': False,
#    'contains(life)': False,
#    'contains(every)': False,
#    'contains(huge)': False,
#    'contains(notable)': False,
#    'contains(example)': False,
#    'contains(created)': False,
#    'contains(show)': False,
#    'contains(english)': False,
#    'contains(fair)': False,
#    'contains(try)': False,
#    'contains(far)': False,
#    'contains(adding)': False,
#    'contains(says)': False,
#    'contains(contributions)': False,
#    'contains(day)': False,
#    'contains(least)': False,
#    'contains(around)': False,
#    'contains(id)': False,
#    'contains(having)': False,
#    'contains(delete)': False,
#    'contains(encyclopedia)': False,
#    'contains(word)': False,
#    'contains(come)': False,
#    'contains(reverted)': True,
#    'contains(consensus)': False,
#    'contains(enough)': False,
#    'contains(ip)': False,
#    'contains(real)': False,
#    'contains(probably)': False,
#    'contains(users)': False,
#    'contains(media)': False,
#    'contains(yes)': False,
#    'contains(given)': False,
#    'contains(through)': False,
#    'contains(war)': False,
#    'contains(simply)': False,
#    'contains(bullshit)': True,
#    'contains(between)': True,
#    'contains(faggot)': False,
#    'contains(clear)': False,
#    'contains(else)': False,
#    'contains(idea)': False,
#    'contains(yet)': False,
#    'contains(correct)': False,
#    'contains(seem)': False,
#    'contains(original)': False,
#    'contains(request)': False,
#    'contains(clearly)': False,
#    'contains(needs)': False,
#    'contains(etc)': False,
#    'contains(consider)': False,
#    'contains(ever)': False,
#    'contains(check)': False,
#    'contains(write)': False,
#    'contains(number)': False,
#    'contains(lot)': False,
#    'contains(pov)': False,
#    'contains(material)': True,
#    'contains(evidence)': False,
#    'contains(view)': False,
#    'contains(states)': False,
#    'contains(3)': False,
#    'contains(quite)': False,
#    'contains(perhaps)': False,
#    'contains(stupid)': False,
#    'contains(instead)': False,
#    'contains(message)': False,
#    'contains(true)': False,
#    'contains(old)': False,
#    'contains(called)': False,
#    'contains(criteria)': False,
#    'contains(support)': False,
#    'contains(until)': False,
#    'contains(written)': False,
#    'contains(post)': False,
#    'contains(saying)': False,
#    'contains(several)': False,
#    'contains(admin)': False,
#    'contains(once)': False,
#    'contains(guidelines)': False,
#    'contains(book)': False,
#    'contains(account)': False,
#    'contains(maybe)': False,
#    'contains(listed)': False,
#    'contains(theres)': False,
#    'contains(fucking)': False,
#    'contains(important)': False,
#    'contains(bit)': False,
#    'contains(group)': False,
#    'contains(title)': False,
#    'contains(changes)': False,
#    'contains(always)': False,
#    'contains(love)': False,
#    'contains(makes)': False,
#    'contains(whether)': False,
#    'contains(words)': False,
#    'contains(further)': False,
#    'contains(mention)': False,
#    'contains(revert)': False,
#    'contains(times)': False,
#    'contains(website)': False,
#    'contains(review)': False,
#    'contains(live)': False,
#    'contains(considered)': True,
#    'contains(term)': False,
#    'contains(version)': False,
#    'contains(following)': False,
#    'contains(regarding)': False,
#    'contains(research)': False,
#    'contains(claim)': False,
#    'contains(means)': False,
#    'contains(language)': False,
#    'contains(bad)': False,
#    'contains(suggest)': False,
#    'contains(main)': False,
#    'contains(address)': False,
#    'contains(kind)': False,
#    'contains(’)': False,
#    'contains(possible)': False,
#    'contains(general)': False,
#    'contains(each)': False,
#    'contains(current)': False,
#    'contains(left)': False,
#    'contains(boobs)': False,
#    'contains(call)': False,
#    'contains(attack)': False,
#    'contains(top)': False,
#    'contains(offfuck)': False,
#    'contains(ok)': False,
#    'contains(statement)': True,
#    'contains(getting)': False,
#    'contains(less)': False,
#    'contains(year)': False,
#    'contains(facts)': False,
#    'contains(second)': False,
#    'contains(man)': False,
#    'contains(whole)': False,
#    'contains(mentioned)': False,
#    'contains(seen)': False,
#    'contains(based)': False,
#    'contains(known)': False,
#    'contains(issues)': False,
#    'contains(topic)': False,
#    'contains(looking)': False,
#    'contains(provide)': False,
#    'contains(start)': False,
#    'contains(boy)': False,
#    'contains(notability)': False,
#    'contains(notice)': False,
#    'contains(template)': False,
#    'contains(answer)': False,
#    'contains(redirect)': False,
#    'contains(guys)': False,
#    'contains(end)': False,
#    'contains(anyway)': False,
#    'contains(interested)': False,
#    'contains(explain)': False,
#    'contains(deneidaccess)': False,
#    'contains(appropriate)': False,
#    'contains(discuss)': False,
#    'contains(create)': False,
#    'contains(course)': False,
#    'contains(happy)': False,
#    'contains(big)': False,
#    'contains(included)': False,
#    'contains(wikipedias)': True,
#    'contains(days)': False,
#    'contains(three)': False,
#    'contains(hey)': False,
#    'contains(away)': False,
#    'contains(info)': False,
#    'contains(sense)': False,
#    'contains(sentence)': False,
#    'contains(include)': False,
#    'contains(per)': False,
#    'contains(shall)': False,
#    'contains(order)': False,
#    'contains(american)': False,
#    'contains(writing)': False,
#    'contains(u)': False,
#    'contains(including)': False,
#    'contains(relevant)': False,
#    'contains(appears)': False,
#    'contains(changed)': False,
#    'contains(line)': False,
#    'contains(full)': False,
#    'contains(rules)': False,
#    'contains(picture)': False,
#    'contains(removing)': False,
#    'contains(style)': False,
#    'contains(date)': False,
#    'contains(according)': False,
#    'contains(related)': False,
#    'contains(due)': False,
#    'contains(project)': False,
#    'contains(later)': False,
#    'contains(web)': False,
#    'contains(god)': False,
#    'contains(although)': False,
#    'contains(currently)': False,
#    'contains(move)': False,
#    'contains(oh)': False,
#    'contains(warning)': True,
#    'contains(within)': False,
#    'contains(common)': False,
#    'contains(s)': False,
#    'contains(certainly)': False,
#    'contains(policies)': False,
#    'contains(myself)': False,
#    'contains(involved)': False,
#    'contains(public)': False,
#    'contains(names)': False,
#    'contains(therefore)': False,
#    'contains(wasnt)': False,
#    'contains(youve)': False,
#    'contains(started)': False,
#    'contains(everything)': False,
#    'contains(claims)': False,
#    'contains(four)': False,
#    'contains(position)': False,
#    'contains(nice)': False,
#    'contains(united)': False,
#    'contains(below)': False,
#    'contains(everyone)': False,
#    'contains(interest)': False,
#    'contains(during)': False,
#    'contains(report)': False,
#    'contains(sign)': False,
#    'contains(response)': False,
#    'contains(false)': True,
#    'contains(wish)': False,
#    'contains(especially)': False,
#    'contains(reasons)': False,
#    'contains(next)': False,
#    'contains(recent)': True,
#    'contains(taken)': False,
#    'contains(stuff)': False,
#    'contains(uploaded)': False,
#    'contains(completely)': False,
#    'contains(specific)': False,
#    'contains(appreciate)': False,
#    'contains(mind)': False,
#    'contains(mamas)': False,
#    'contains(able)': True,
#    'contains(attacks)': False,
#    'contains(community)': False,
#    'contains(2005)': False,
#    'contains(contribs)': False,
#    'contains(wont)': False,
#    'contains(asked)': True,
#    'contains(today)': False,
#    'contains(guess)': False,
#    'contains(hard)': False,
#    'contains(news)': False,
#    'contains(looks)': False,
#    'contains(similar)': False,
#    'contains(4)': False,
#    'contains(pretty)': False,
#    'contains(itself)': False,
#    'contains(lead)': False,
#    'contains(system)': False,
#    'contains(neutral)': False,
#    'contains(wanted)': False,
#    'contains(school)': False,
#    'contains(edited)': False,
#    'contains(obviously)': False,
#    'contains(country)': False,
#    'contains(paragraph)': False,
#    'contains(boymamas)': False,
#    'contains(official)': False,
#    'contains(single)': False,
#    'contains(past)': False,
#    'contains(game)': False,
#    'contains(nor)': False,
#    'contains(5)': False,
#    'contains(email)': False,
#    'contains(learn)': False,
#    'contains(summary)': False,
#    'contains(process)': False,
#    'contains(whatever)': False,
#    'contains(unless)': False,
#    'contains(dispute)': False,
#    'contains(talking)': False,
#    'contains(themselves)': False,
#    'contains(“)': False,
#    'contains(quote)': False,
#    'contains(points)': False,
#    'contains(placed)': False,
#    'contains(remember)': False,
#    'contains(faith)': False,
#    'contains(penis)': False,
#    'contains(shit)': False,
#    'contains(political)': False,
#    'contains(useful)': False,
#    'contains(provided)': False,
#    'contains(particular)': False,
#    'contains(power)': False,
#    'contains(future)': False,
#    'contains(search)': False,
#    'contains(entry)': False,
#    'contains(wrote)': False,
#    'contains(anonymous)': False,
#    'contains(published)': False,
#    'contains(stay)': False,
#    'contains(came)': False,
#    'contains(side)': False,
#    'contains(working)': False,
#    'contains(status)': False,
#    'contains(ago)': False,
#    'contains(reading)': False,
#    'contains(admins)': False,
#    'contains(havent)': False,
#    'contains(recently)': False,
#    'contains(present)': False,
#    'contains(argument)': False,
#    'contains(reverting)': False,
#    'contains(exactly)': False,
#    'contains(knowledge)': False,
#    'contains(british)': False,
#    'contains(government)': False,
#    'contains(rule)': False,
#    'contains(noticed)': False,
#    'contains(lets)': False,
#    'contains(cheers)': False,
#    'contains(terms)': False,
#    'contains(books)': False,
#    'contains(takes)': False,
#    'contains(fine)': False,
#    'contains(vandalize)': False,
#    'contains(city)': False,
#    'contains(truth)': False,
#    'contains(tags)': False,
#    'contains(sandbox)': False,
#    'contains(”)': False,
#    'contains(ones)': False,
#    'contains(appear)': False,
# ...
#    'contains(writing)': False,
#    'contains(u)': False,
#    'contains(including)': False,
#    'contains(relevant)': False,
#    'contains(appears)': False,
#    'contains(changed)': False,
#    'contains(line)': False,
#    'contains(full)': False,
#    'contains(rules)': False,
#    'contains(picture)': False,
#    'contains(removing)': False,
#    'contains(style)': False,
#    'contains(date)': False,
#    'contains(according)': False,
#    'contains(related)': False,
#    'contains(due)': False,
#    'contains(project)': False,
#    'contains(later)': False,
#    'contains(web)': False,
#    'contains(god)': False,
#    'contains(although)': False,
#    'contains(currently)': False,
#    'contains(move)': False,
#    'contains(oh)': False,
#    'contains(warning)': False,
#    'contains(within)': False,
#    'contains(common)': False,
#    'contains(s)': False,
#    'contains(certainly)': False,
#    'contains(policies)': False,
#    'contains(myself)': False,
#    'contains(involved)': False,
#    'contains(public)': False,
#    'contains(names)': False,
#    'contains(therefore)': False,
#    'contains(wasnt)': False,
#    'contains(youve)': False,
#    'contains(started)': False,
#    'contains(everything)': False,
#    'contains(claims)': False,
#    'contains(four)': False,
#    'contains(position)': False,
#    'contains(nice)': False,
#    'contains(united)': False,
#    'contains(below)': False,
#    'contains(everyone)': False,
#    'contains(interest)': False,
#    'contains(during)': False,
#    'contains(report)': False,
#    'contains(sign)': False,
#    'contains(response)': False,
#    'contains(false)': False,
#    'contains(wish)': False,
#    'contains(especially)': False,
#    'contains(reasons)': False,
#    'contains(next)': False,
#    'contains(recent)': False,
#    'contains(taken)': False,
#    'contains(stuff)': False,
#    'contains(uploaded)': False,
#    'contains(completely)': False,
#    'contains(specific)': False,
#    'contains(appreciate)': False,
#    'contains(mind)': False,
#    'contains(mamas)': False,
#    'contains(able)': False,
#    'contains(attacks)': False,
#    'contains(community)': False,
#    'contains(2005)': False,
#    'contains(contribs)': False,
#    'contains(wont)': False,
#    'contains(asked)': False,
#    'contains(today)': False,
#    'contains(guess)': False,
#    'contains(hard)': False,
#    'contains(news)': False,
#    'contains(looks)': False,
#    'contains(similar)': False,
#    'contains(4)': False,
#    'contains(pretty)': False,
#    'contains(itself)': False,
#    'contains(lead)': False,
#    'contains(system)': False,
#    'contains(neutral)': False,
#    'contains(wanted)': False,
#    'contains(school)': False,
#    'contains(edited)': False,
#    'contains(obviously)': False,
#    'contains(country)': False,
#    'contains(paragraph)': False,
#    'contains(boymamas)': False,
#    'contains(official)': False,
#    'contains(single)': False,
#    'contains(past)': False,
#    'contains(game)': False,
#    'contains(nor)': False,
#    'contains(5)': False,
#    'contains(email)': False,
#    'contains(learn)': False,
#    'contains(summary)': False,
#    'contains(process)': False,
#    'contains(whatever)': False,
#    'contains(unless)': False,
#    'contains(dispute)': False,
#    'contains(talking)': False,
#    'contains(themselves)': False,
#    'contains(“)': False,
#    'contains(quote)': False,
#    'contains(points)': False,
#    'contains(placed)': False,
#    'contains(remember)': False,
#    'contains(faith)': False,
#    'contains(penis)': False,
#    'contains(shit)': False,
#    'contains(political)': False,
#    'contains(useful)': False,
#    'contains(provided)': False,
#    'contains(particular)': False,
#    'contains(power)': False,
#    'contains(future)': False,
#    'contains(search)': False,
#    'contains(entry)': False,
#    'contains(wrote)': False,
#    'contains(anonymous)': False,
#    'contains(published)': False,
#    'contains(stay)': False,
#    'contains(came)': False,
#    'contains(side)': False,
#    'contains(working)': False,
#    'contains(status)': False,
#    'contains(ago)': False,
#    'contains(reading)': False,
#    'contains(admins)': False,
#    'contains(havent)': False,
#    'contains(recently)': False,
#    'contains(present)': False,
#    'contains(argument)': False,
#    'contains(reverting)': False,
#    'contains(exactly)': False,
#    'contains(knowledge)': False,
#    'contains(british)': False,
#    'contains(government)': False,
#    'contains(rule)': False,
#    'contains(noticed)': False,
#    'contains(lets)': False,
#    'contains(cheers)': False,
#    'contains(terms)': False,
#    'contains(books)': False,
#    'contains(takes)': False,
#    'contains(fine)': False,
#    'contains(vandalize)': False,
#    'contains(city)': False,
#    'contains(truth)': False,
#    'contains(tags)': False,
#    'contains(sandbox)': False,
#    'contains(”)': False,
#    'contains(ones)': False,
#    'contains(appear)': False,
#    'contains(often)': False,
#    'contains(hes)': False,
#    'contains(views)': False,
#    'contains(rape)': False,
#    'contains(major)': False,
#    'contains(regards)': False,
#    'contains(deleting)': False,
#    'contains(description)': False,
#    'contains(follow)': False,
#    'contains(definition)': False,
#    'contains(google)': False,
#    'contains(problems)': False,
#    'contains(become)': False,
#    'contains(saw)': False,
#    'contains(company)': False,
#    'contains(music)': False,
#    'contains(taking)': False,
#    'contains(t)': False,
#    'contains(along)': False,
#    'contains(explanation)': False,
#    'contains(moved)': False,
#    'contains(generally)': False,
#    'contains(username)': False,
#    'contains(2007)': False,
#    'contains(proper)': False,
#    'contains(law)': False,
#    'contains(administrator)': False,
#    'contains(film)': False,
#    'contains(attention)': False,
#    'contains(improve)': False,
#    'contains(posted)': False,
#    'contains(otherwise)': False,
#    'contains(aware)': False,
#    'contains(needed)': False,
#    'contains(valid)': False,
#    'contains(alone)': False,
#    'contains(external)': False,
#    'contains(band)': False,
#    'contains(five)': False,
#    'contains(shows)': False,
#    'contains(likely)': False,
#    'contains(disagree)': False,
#    'contains(sort)': False,
#    'contains(wp)': False,
#    'contains(almost)': False,
#    'contains(ie)': False,
#    'contains(arent)': False,
#    'contains(2004)': False,
#    'contains(bastard)': False,
#    'contains(indeed)': False,
#    'contains(party)': False,
#    'contains(10)': False,
#    'contains(shouldnt)': False,
#    'contains(certain)': False,
#    'contains(form)': False,
#    'contains(set)': False,
#    'contains(c)': False,
#    'contains(file)': False,
#    'contains(contributing)': False,
#    'contains(hell)': True,
#    'contains(allowed)': False,
#    'contains(sections)': False,
#    'contains(stated)': False,
#    'contains(took)': False,
#    'contains(2008)': False,
#    'contains(high)': False,
#    'contains(thus)': False,
#    'contains(available)': False,
#    'contains(national)': False,
#    'contains(team)': False,
#    'contains(2006)': False,
#    'contains(simple)': False,
#    'contains(whats)': False,
#    'contains(internet)': False,
#    'contains(small)': False,
#    'contains(mr)': False,
#    'contains(entire)': False,
#    'contains(guy)': False,
#    'contains(works)': False,
#    'contains(re)': False,
#    'contains(tagged)': False,
#    'contains(actions)': False,
#    'contains(interesting)': False,
#    'contains(citations)': False,
#    'contains(citation)': False,
#    'contains(greek)': False,
#    'contains(bias)': False,
#    'contains(rights)': False,
#    'contains(cited)': False,
#    'contains(members)': False,
#    'contains(tried)': False,
#    'contains(short)': False,
#    'contains(longer)': False,
#    'contains(area)': False,
#    'contains(obvious)': False,
#    'contains(banned)': False,
#    'contains(proposed)': False,
#    'contains(large)': False,
#    'contains(decide)': False,
#    'contains(fggt)': False,
#    'contains(wouldnt)': False,
#    'contains(sites)': False,
#    'contains(happened)': False,
#    'contains(various)': False,
#    'contains(sourced)': False,
#    'contains(result)': False,
#    'contains(npov)': False,
#    'contains(open)': False,
#    'contains(addition)': False,
#    'contains(week)': False,
#    'contains(together)': False,
#    'contains(contact)': False,
#    'contains(act)': False,
#    'contains(test)': False,
#    'contains(actual)': False,
#    'contains(john)': False,
#    'contains(category)': False,
#    'contains(type)': False,
#    'contains(accurate)': False,
#    'contains(exist)': False,
#    'contains(yeah)': False,
#    'contains(author)': False,
#    'contains(chicken)': False,
#    'contains(deletedthis)': False,
#    'contains(family)': False,
#    'contains(biased)': False,
#    'contains(goes)': False,
#    'contains(–)': False,
#    'contains(force)': False,
#    'contains(enjoy)': False,
#    'contains(context)': False,
#    'contains(himself)': False,
#    'contains(upon)': False,
#    'contains(speak)': False,
#    'contains(fan1967)': False,
#    'contains(indicate)': False,
#    'contains(theory)': False,
#    'contains(military)': False,
#    'contains(reply)': False,
#    'contains(story)': False,
#    'contains(2010)': False,
#    'contains(worked)': False,
#    'contains(white)': False,
#    'contains(level)': False,
#    'contains(licker)': False,
#    'contains(avoid)': False,
#    'contains(attempt)': False,
#    'contains(serious)': False,
#    'contains(hand)': False,
#    'contains(seriously)': False,
#    'contains(comes)': False,
#    'contains(violation)': False,
#    'contains(told)': False,
#    'contains(criticism)': False,
#    'contains(went)': False,
#    'contains(action)': False,
#    'contains(human)': False,
#    'contains(german)': False,
#    'contains(copy)': False,
#    'contains(b)': False,
#    'contains(hours)': False,
#    'contains(proof)': False,
#    'contains(deal)': False,
#    'contains(nonsense)': False,
#    'contains(automatically)': False,
#    'contains(assume)': False,
#    'contains(difference)': False,
#    'contains(helpful)': False,
#    'contains(cite)': False,
#    'contains(accept)': False,
#    'contains(doubt)': False,
#    'contains(face)': False,
#    'contains(church)': False,
#    'contains(soon)': False,
#    'contains(uk)': False,
#    'contains(rationale)': False,
#    'contains(multiple)': False,
#    'contains(record)': False,
#    'contains(cause)': False,
#    'contains(theyre)': False,
#    'contains(opinions)': False,
#    'contains(complete)': False,
#    'contains(science)': False,
#    'contains(ricehey)': False,
#    'contains(space)': False,
#    'contains(conflict)': False,
#    'contains(specifically)': False,
#    'contains(death)': False,
#    'contains(online)': False,
#    'contains(personally)': False,
#    'contains(significant)': False,
#    'contains(gay)': False,
#    'contains(earlier)': False,
#    'contains(sometimes)': False,
#    'contains(outside)': False,
#    'contains(job)': False,
#    'contains(respect)': False,
#    'contains(details)': False,
#    'contains(youll)': False,
#    'contains(necessary)': False,
#    'contains(neither)': False,
#    'contains(purpose)': False,
#    'contains(series)': False,
#    'contains(period)': False,
#    'contains(asking)': False,
#    'contains(inclusion)': False,
#    'contains(accepted)': False,
#    'contains(previous)': False,
#    'contains(calling)': False,
#    'contains(philippineslong)': False,
#    'contains(gets)': False,
#    'contains(separate)': False,
#    'contains(situation)': False,
#    'contains(box)': False,
#    'contains(ban)': False,
#    'contains(heard)': False,
#    'contains(discussed)': False,
#    'contains(none)': False,
#    'contains(months)': False,
#    'contains(statements)': False,
#    'contains(tildes)': False,
#    'contains(supposed)': False,
#    'contains(mongo)': False,
#    'contains(numbers)': False,
#    'contains(subjects)': False,
#    'contains(unfortunately)': False,
#    'contains(black)': False,
#    'contains(incorrect)': False,
#    'contains(gave)': False,
#    'contains(character)': False,
#    'contains(legal)': False,
#    'contains(explaining)': False,
#    'contains(behavior)': False,
#    'contains(prove)': False,
#    'contains(wikiproject)': False,
#    'contains(weezer)': False,
#    'contains(bring)': False,
#    'contains(afd)': False,
#    'contains(standard)': False,
#    'contains(lost)': False,
#    'contains(computer)': False,
#    'contains(million)': False,
#    'contains(okay)': False,
#    'contains(fix)': False,
#    'contains(okayis)': False,
#    'contains(manual)': False,
#    'contains(friend)': False,
#    'contains(20)': False,
#    'contains(particularly)': False,
#    'contains(cases)': False,
#    'contains(release)': False,
#    'contains(usually)': False,
#    'contains(living)': False,
#    'contains(head)': False,
#    'contains(uses)': False,
#    'contains(except)': False,
#    'contains(coming)': False,
#    'contains(rest)': False,
#    'contains(field)': False,
#    'contains(6)': False,
#    'contains(concerns)': False,
#    'contains(couple)': False,
#    'contains(piece)': False,
#    'contains(described)': False,
#    'contains(civil)': False,
#    'contains(examples)': False,
#    'contains(existing)': False,
#    'contains(thinking)': False,
#    'contains(linked)': False,
#    'contains(changing)': False,
#    'contains(directly)': False,
#    'contains(wikipedian)': False,
#    'contains(french)': False,
#    'contains(july)': False,
#    'contains(among)': False,
#    'contains(happen)': False,
#    'contains(possibly)': False,
#    'contains(entirely)': False,
#    'contains(album)': False,
#    'contains(creating)': False,
#    'contains(debate)': False,
#    'contains(data)': False,
#    'contains(song)': False,
#    'contains(june)': False,
#    'contains(refer)': False,
#    'contains(contribute)': False,
#    'contains(verifiable)': False,
#    'contains(7)': False,
#    'contains(october)': False,
#    'contains(play)': False,
#    'contains(removal)': False,
#    'contains(totally)': False,
#    'contains(blocking)': False,
#    'contains(2009)': False,
#    'contains(decision)': False,
#    'contains(jews)': False,
#    'contains(lack)': False,
#    'contains(readers)': False,
#    'contains(reported)': False,
#    'contains(culture)': False,
#    'contains(unblock)': False,
#    'contains(meaning)': False,
#    'contains(sucks)': False,
#    'contains(across)': False,
#    'contains(third)': False,
#    'contains(despite)': False,
#    'contains(majority)': False,
#    'contains(august)': False,
#    'contains(photo)': False,
#    'contains(club)': False,
#    'contains(noted)': False,
#    'contains(early)': False,
#    'contains(vs)': False,
#    'contains(historical)': False,
#    'contains(close)': False,
#    'contains(putting)': False,
#    'contains(final)': False,
#    'contains(disruptive)': False,
#    'contains(100)': False,
#    'contains(meet)': False,
#    'contains(access)': False,
#    'contains(friends)': False,
#    'contains(court)': False,
#    'contains(meant)': False,
#    'contains(absolutely)': False,
#    'contains(modern)': False,
#    'contains(groups)': False,
#    'contains(video)': False,
#    'contains(websites)': False,
#    'contains(knows)': False,
#    'contains(wait)': False,
#    'contains(chance)': False,
#    'contains(run)': False,
#    'contains(contest)': False,
#    'contains(primary)': False,
#    'contains(easy)': False,
#    'contains(pillars)': False,
#    'contains(christian)': False,
#    'contains(loser)': False,
#    'contains(religion)': False,
#    'contains(8)': False,
#    'contains(university)': False,
#    'contains(results)': False,
#    'contains(home)': False,
#    'contains(pictures)': False,
#    'contains(born)': False,
#    'contains(straight)': False,
#    'contains(events)': False,
#    'contains(unsigned)': False,
#    'contains(towards)': False,
#    'contains(member)': False,
#    'contains(24)': False,
#    'contains(posts)': False,
#    'contains(youd)': False,
#    'contains(eg)': False,
#    'contains(standards)': False,
#    'contains(error)': False,
#    'contains(scientific)': False,
#    'contains(dear)': False,
#    'contains(tutorial)': False,
#    'contains(discussing)': False,
#    'contains(countries)': False,
#    'contains(inappropriate)': False,
#    'contains(control)': False,
#    'contains(body)': False,
#    'contains(march)': False,
#    'contains(behind)': False,
#    'contains(service)': False,
#    'contains(giving)': False,
#    'contains(decided)': False,
#    'contains(named)': False,
#    'contains(2011)': False,
#    'contains(quality)': False,
#    ...})]

# %%
#Esto no aparece en el capitulo
# 11) Experimento: distintos tamaños de vocabulario
for size in [1000, 2000, 5000]:
    word_feats = list(FreqDist(w for tokens in df['tokens'] for w in tokens))[:size]
    def feats(tokens): return {f'contains({w})': (w in set(tokens)) for w in word_feats}
    fs = [(feats(t), l) for t,l in zip(df['tokens'], df['label'])]
    random.shuffle(fs)
    n = len(fs)
    train, dev = fs[:int(0.7*n)], fs[int(0.7*n):int(0.85*n)]
    acc = accuracy(NaiveBayesClassifier.train(train), dev)
    print(f"Vocab size {size}: Dev accuracy = {acc:.4f}")
# Out:
# Vocab size 1000: Dev accuracy = 0.6463
# Vocab size 2000: Dev accuracy = 0.6387
# Vocab size 5000: Dev accuracy = 0.6400

# %%
# Función mejorada con sufijos y bigramas
from nltk import bigrams

# Función mejorada con sufijos y bigramas
def rich_features(tokens):
    tokens_set = set(tokens)
    feats = {f'contains({w})': (w in tokens_set) for w in word_features}
    # sufijos
    feats['suffix1'] = tokens[-1] if tokens else ''
    # suffix2 como concatenación de los últimos dos caracteres
    feats['suffix2'] = ''.join(tokens[-2:]) if len(tokens) >= 2 else ''
    # bigramas frecuentes
    from nltk import bigrams
    for bg in bigrams(tokens):
        feats[f'bigram({bg[0]}_{bg[1]})'] = True
    return feats

# Entrenar y evaluar con rich_features
fs_rich = [(rich_features(t), l) for t,l in zip(df['tokens'], df['label'])]
random.shuffle(fs_rich)
n = len(fs_rich)
train_r, dev_r = fs_rich[:int(0.7*n)], fs_rich[int(0.7*n):int(0.85*n)]
clf_rich = NaiveBayesClassifier.train(train_r)
print("Dev accuracy con rich features:", accuracy(clf_rich, dev_r))
# Out:
# Dev accuracy con rich features: 0.6773333333333333

# %% [markdown]
# Section 3

# %%
# 1) Imports y configuración
import nltk
import pandas as pd
import random
import string
from nltk import FreqDist
from nltk.classify import NaiveBayesClassifier
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Asegurar recursos NLTK
nltk.download('punkt')
nltk.download('punkt_tab')

# Cargar y tokenizar (usando preprocesado del capítulo 6)
def load_and_tokenize(path='Dataset/train.csv', sample_size=20000):
    df = pd.read_csv(path)[['comment_text','toxic']].dropna()
    df['label'] = df['toxic'].map({1:'toxic',0:'non_toxic'})
    df = df.sample(sample_size, random_state=42)

    # Preprocesado y tokenización
    def preprocess_and_tokenize(text):
        text = text.lower()
        text = ''.join(ch for ch in text if ch not in string.punctuation)
        return nltk.word_tokenize(text)
    df['tokens'] = df['comment_text'].apply(preprocess_and_tokenize)
    return df.reset_index(drop=True)

# Cargar datos
df = load_and_tokenize()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hugom\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hugom\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# 2) Construir featureset y división Training/Dev/Test
all_words = FreqDist(w for tokens in df['tokens'] for w in tokens)
word_features = list(all_words)[:2000]

def doc_feats(tokens):
    s = set(tokens)
    return {f'contains({w})': (w in s) for w in word_features}

# Crear featuresets
features = [(doc_feats(t), l) for t,l in zip(df['tokens'], df['label'])]
random.shuffle(features)

# Divisiones
n = len(features)
train = features[:int(0.7*n)]
dev   = features[int(0.7*n):int(0.85*n)]
test  = features[int(0.85*n):]

print("Tamaños: Train=", len(train), "Dev=", len(dev), "Test=", len(test))
# Out:
# Tamaños: Train= 14000 Dev= 3000 Test= 3000

# %%
# 3) Accuracy en Dev
clf = NaiveBayesClassifier.train(train)
accuracy_dev = nltk.classify.accuracy(clf, dev)
print(f"Dev Accuracy: {accuracy_dev:.4f}")
# Out:
# Dev Accuracy: 0.6447

# %%
# 4) Precision, Recall y F1 en Test
y_true = [label for (_,label) in test]
y_pred = [clf.classify(feats) for (feats,_) in test]

prfs = precision_recall_fscore_support(y_true, y_pred, labels=['toxic','non_toxic'], average=None)
print("Precision, Recall, F1 por clase:\n", prfs)
print("\nReporte completo:\n", classification_report(y_true, y_pred))
# Out:
# Precision, Recall, F1 por clase:
#  (array([0.1822542 , 0.97026872]), array([0.81428571, 0.62389706]), array([0.29784455, 0.75945402]), array([ 280, 2720]))
#
# Reporte completo:
#                precision    recall  f1-score   support
#
#    non_toxic       0.97      0.62      0.76      2720
#        toxic       0.18      0.81      0.30       280
#
#     accuracy                           0.64      3000
#    macro avg       0.58      0.72      0.53      3000
# weighted avg       0.90      0.64      0.72      3000

# %%
# 6) Cross-Validation con Naive Bayes (manual usando StratifiedKFold)
from sklearn.model_selection import StratifiedKFold
import numpy as np

# Preparar etiquetas y folds
labels = np.array([l for _,l in features])
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_scores = []
for train_idx, test_idx in skf.split(features, labels):
    train_fs = [features[i] for i in train_idx]
    test_fs  = [features[i] for i in test_idx]
    clf_cv = NaiveBayesClassifier.train(train_fs)
    acc = nltk.classify.accuracy(clf_cv, test_fs)
    cv_scores.append(acc)

print("Cross-Val Accuracies:", cv_scores)
print(f"Mean CV Accuracy: {np.mean(cv_scores):.4f} ± {np.std(cv_scores):.4f}")
# Out:
# Cross-Val Accuracies: [0.6455, 0.6445, 0.64875, 0.65, 0.65525]
# Mean CV Accuracy: 0.6488 ± 0.0038
